# %%
from src.models import engine
from utils import utils
import torch
from torch.utils.data import DataLoader
from torch.optim import Adam
from importlib import reload

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
vae = engine.VAE(input_shape=(3,128,128), 
              channels_enc=[8, 32, 64],
              channels_dec=[32, 8, 3],
              kernel_enc=[3, 3, 3, 3],
              kernel_dec=[3, 3, 3, 3],
              latent_dim=512,
              target_shape=(128,128))

# %%
training_data, test_data = utils.load_CelebA("train"), utils.load_CelebA("test")

# %%
train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)

# %%
criterion = utils.criterion(beta=1e-2)
optimizer = Adam(vae.parameters(), lr=5e-4)

engine.train_vae(vae, train_dataloader, nb_epochs=2, criterion=utils.criterion(1e-2), optimizer=optimizer, device=device)
# Out:
# 3it [00:00,  7.51it/s]
# Epoch 0, Batch 0 : BCE = 0.7068576216697693, KL = 2.0581901480909437e-06
# 103it [00:07, 14.42it/s]
# Epoch 0, Batch 100 : BCE = 0.5506973266601562, KL = 0.004096416290849447
# 203it [00:14, 14.79it/s]
# Epoch 0, Batch 200 : BCE = 0.5478152632713318, KL = 0.005704352166503668
# 303it [00:21, 13.84it/s]
# Epoch 0, Batch 300 : BCE = 0.534935474395752, KL = 0.00599297322332859
# 403it [00:28, 14.69it/s]
# Epoch 0, Batch 400 : BCE = 0.5192212462425232, KL = 0.006341376807540655
# 503it [00:35, 14.66it/s]
# Epoch 0, Batch 500 : BCE = 0.5136730074882507, KL = 0.006641100626438856
# 603it [00:42, 14.63it/s]
# Epoch 0, Batch 600 : BCE = 0.5293134450912476, KL = 0.00606357678771019
# 703it [00:49, 14.55it/s]
# Epoch 0, Batch 700 : BCE = 0.5061924457550049, KL = 0.006161264143884182
# 803it [00:56, 14.37it/s]
# Epoch 0, Batch 800 : BCE = 0.5022546052932739, KL = 0.006963132414966822
# 903it [01:03, 13.96it/s]
# Epoch 0, Batch 900 : BCE = 0.4878764748573303, KL = 0.006907016504555941
# 1003it [01:10, 14.37it/s]
# Epoch 0, Batch 1000 : BCE = 0.4960077702999115, KL = 0.007090081460773945
# 1103it [01:17, 14.30it/s]
# Epoch 0, Batch 1100 : BCE = 0.505555272102356, KL = 0.006297849118709564
# 1203it [01:24, 14.37it/s]
# Epoch 0, Batch 1200 : BCE = 0.5096836090087891, KL = 0.00666798697784543
# 1303it [01:31, 14.29it/s]
# Epoch 0, Batch 1300 : BCE = 0.5087494850158691, KL = 0.007072577252984047
# 1403it [01:37, 14.33it/s]
# Epoch 0, Batch 1400 : BCE = 0.5095911026000977, KL = 0.006297961343079805
# 1503it [01:44, 14.42it/s]
# Epoch 0, Batch 1500 : BCE = 0.5015484094619751, KL = 0.006632289849221706
# 1603it [01:51, 14.51it/s]
# Epoch 0, Batch 1600 : BCE = 0.48938092589378357, KL = 0.006670791190117598
# 1703it [01:58, 14.48it/s]
# Epoch 0, Batch 1700 : BCE = 0.5054494142532349, KL = 0.006646566092967987
# 1803it [02:05, 14.61it/s]
# Epoch 0, Batch 1800 : BCE = 0.5134122371673584, KL = 0.005908818915486336
# 1903it [02:12, 14.64it/s]
# Epoch 0, Batch 1900 : BCE = 0.5060358047485352, KL = 0.006788345519453287
# 2003it [02:19, 14.68it/s]
# Epoch 0, Batch 2000 : BCE = 0.492938369512558, KL = 0.00646124966442585
# 2103it [02:26, 14.61it/s]
# Epoch 0, Batch 2100 : BCE = 0.4974479079246521, KL = 0.006393989082425833
# 2203it [02:32, 14.60it/s]
# Epoch 0, Batch 2200 : BCE = 0.4906148910522461, KL = 0.0062893470749258995
# 2303it [02:39, 14.64it/s]
# Epoch 0, Batch 2300 : BCE = 0.49100762605667114, KL = 0.006582912057638168
# 2403it [02:46, 14.71it/s]
# Epoch 0, Batch 2400 : BCE = 0.49157318472862244, KL = 0.006308975629508495
# 2503it [02:53, 14.71it/s]
# Epoch 0, Batch 2500 : BCE = 0.49425172805786133, KL = 0.006644630338996649
# 2544it [02:55, 14.47it/s]
# 2it [00:00, 13.81it/s]
# Epoch 1, Batch 0 : BCE = 0.5022857189178467, KL = 0.006324807647615671
# 102it [00:06, 14.60it/s]
# Epoch 1, Batch 100 : BCE = 0.49959081411361694, KL = 0.006721767131239176
# 202it [00:13, 14.71it/s]
# Epoch 1, Batch 200 : BCE = 0.5042665004730225, KL = 0.0065152267925441265
# 302it [00:20, 14.70it/s]
# Epoch 1, Batch 300 : BCE = 0.4812891185283661, KL = 0.006685872096568346
# 402it [00:27, 14.35it/s]
# Epoch 1, Batch 400 : BCE = 0.4824945628643036, KL = 0.006514763459563255
# 502it [00:34, 14.28it/s]
# Epoch 1, Batch 500 : BCE = 0.4878867268562317, KL = 0.006715487223118544
# 602it [00:41, 14.33it/s]
# Epoch 1, Batch 600 : BCE = 0.5130296945571899, KL = 0.0064962077885866165
# 702it [00:48, 14.31it/s]
# Epoch 1, Batch 700 : BCE = 0.49386486411094666, KL = 0.006429450586438179
# 802it [00:55, 13.02it/s]
# Epoch 1, Batch 800 : BCE = 0.5054205656051636, KL = 0.006677230354398489
# 902it [01:03, 12.04it/s]
# Epoch 1, Batch 900 : BCE = 0.4944048821926117, KL = 0.006721987389028072
# 1002it [01:10, 12.07it/s]
# Epoch 1, Batch 1000 : BCE = 0.49534040689468384, KL = 0.006651191506534815
# 1104it [01:17, 14.72it/s]
# Epoch 1, Batch 1100 : BCE = 0.4887821078300476, KL = 0.006481190677732229
# 1202it [01:24, 14.61it/s]
# Epoch 1, Batch 1200 : BCE = 0.4828389883041382, KL = 0.00651076203212142
# 1302it [01:30, 14.29it/s]
# Epoch 1, Batch 1300 : BCE = 0.49922284483909607, KL = 0.007014913950115442
# 1402it [01:37, 14.18it/s]
# Epoch 1, Batch 1400 : BCE = 0.5009336471557617, KL = 0.006589541211724281
# 1502it [01:44, 14.28it/s]
# Epoch 1, Batch 1500 : BCE = 0.48683470487594604, KL = 0.006810798309743404
# 1602it [01:51, 14.28it/s]
# Epoch 1, Batch 1600 : BCE = 0.5030080676078796, KL = 0.00653323857113719
# 1704it [01:58, 14.79it/s]
# Epoch 1, Batch 1700 : BCE = 0.47730112075805664, KL = 0.006388341076672077
# 1802it [02:05, 14.73it/s]
# Epoch 1, Batch 1800 : BCE = 0.5047842264175415, KL = 0.006456790957599878
# 1902it [02:12, 14.33it/s]
# Epoch 1, Batch 1900 : BCE = 0.49890053272247314, KL = 0.006602183450013399
# 2002it [02:19, 14.31it/s]
# Epoch 1, Batch 2000 : BCE = 0.5087488889694214, KL = 0.006319854874163866
# 2102it [02:26, 14.15it/s]
# Epoch 1, Batch 2100 : BCE = 0.48541948199272156, KL = 0.006776375230401754
# 2202it [02:32, 14.57it/s]
# Epoch 1, Batch 2200 : BCE = 0.4839852452278137, KL = 0.006585352122783661
# 2302it [02:39, 14.21it/s]
# Epoch 1, Batch 2300 : BCE = 0.5147783756256104, KL = 0.006404616869986057
# 2402it [02:46, 14.19it/s]
# Epoch 1, Batch 2400 : BCE = 0.5005176067352295, KL = 0.0068511804565787315
# 2502it [02:53, 14.28it/s]
# Epoch 1, Batch 2500 : BCE = 0.5032811164855957, KL = 0.006659528240561485
# 2544it [02:56, 14.41it/s]

# %%
X,_,_ = vae(training_data[0][0].unsqueeze(0).to(device))

# %%
utils.plot_image(X.squeeze(0))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
utils.plot_image(training_data[0][0])
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
utils.generate_img(vae, device, seed=32)
